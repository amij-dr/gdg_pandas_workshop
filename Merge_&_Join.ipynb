# %% [markdown]
# # **Pandas - Merge and Join**

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/[Datasets] Intermediate Pandas/product_cat.csv')

# %%
df1
# Out:
#   Product ID       Product Name         Category
# 0    FUR-001  Conference Tables        Furniture
# 1    FUR-003               Lamp        Furniture
# 2    OFF-001            Crayons  Office Supplies
# 3    TEC-001     Wireless Mouse       Technology
# 4    TEC-003        Flash Drive       Technology

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/[Datasets] Intermediate Pandas/product_price.csv')

# %%
df2

# %% [markdown]
# #**Merge**

# %% [markdown]
# > `.merge()` function allows us to merge two DataFrames based on common columns or indexes (similar to SQL join)

# %% [markdown]
# df1 will be the left DataFrame, and df2 on the right.

# %%
df1.merge(df2)
# Out:
#   Product ID       Product Name    Price    Category
# 0    FUR-001  Conference Tables  292.100   Furniture
# 1    TEC-001     Wireless Mouse   39.992  Technology

# %% [markdown]
# `how` - specifies the method of merging, default is `inner` which is the intersection of keys from both frames
#
# `on` - to specify which column/s to join on, default is the intersection of the columns present in both DataFrames.

# %%
df1.merge(df2, how='inner', on='Product ID')
# Out:
#   Product ID     Product Name_x    Price     Product Name_y    Category
# 0    FUR-001  Conference Tables  292.100  Conference Tables   Furniture
# 1    TEC-001     Wireless Mouse   39.992     Wireless Mouse  Technology

# %%
df1.merge(df2, how='inner', on=['Product ID', 'Product Name'])
# Out:
#   Product ID       Product Name    Price    Category
# 0    FUR-001  Conference Tables  292.100   Furniture
# 1    TEC-001     Wireless Mouse   39.992  Technology

# %% [markdown]
# `inner` returns to us a DataFrame consisting of rows that are both `df1` and `df2`. `total rows = rows of df1 ⋂ rows of df2 `
#
# `outer` returns a DataFrame consisting of all rows that are either in `df1` or `df2`. `total rows = rows of df1 ⋃ rows of df2`
#
# If a row does not have a column value for a column of another DataFrame, it returns a NaN

# %%
df1.merge(df2, how='outer')
# Out:
#   Product ID       Product Name     Price         Category
# 0    FUR-001  Conference Tables   292.100        Furniture
# 1    FUR-002          Bookcases  3406.664              NaN
# 2    FUR-003               Lamp       NaN        Furniture
# 3    OFF-001            Crayons       NaN  Office Supplies
# 4    TEC-001     Wireless Mouse    39.992       Technology
# 5    TEC-002            Headset    22.000              NaN
# 6    TEC-003        Flash Drive       NaN       Technology

# %% [markdown]
# `left` gets all the rows from `df1`. If there are overlapping data with `df2`, get the overlapping column values. NaN for those without.

# %%
df1.merge(df2, how='left')
# Out:
#   Product ID       Product Name     Price    Category
# 0    FUR-001  Conference Tables   292.100   Furniture
# 1    FUR-002          Bookcases  3406.664         NaN
# 2    TEC-001     Wireless Mouse    39.992  Technology
# 3    TEC-002            Headset    22.000         NaN

# %% [markdown]
# `right` get all rows from` df2`, If there are overlapping data with df1, get the overlapping column values. NaN for those without

# %%
df1.merge(df2, how='right')
# Out:
#   Product ID       Product Name    Price         Category
# 0    FUR-001  Conference Tables  292.100        Furniture
# 1    FUR-003               Lamp      NaN        Furniture
# 2    OFF-001            Crayons      NaN  Office Supplies
# 3    TEC-001     Wireless Mouse   39.992       Technology
# 4    TEC-003        Flash Drive      NaN       Technology

# %% [markdown]
# `cross` returns a cartesian product of all rows following the order of the left DataFrame

# %%
df1.merge(df2, how='cross')
# Out:
#    Product ID_x     Product Name_x     Price Product ID_y     Product Name_y  \
# 0       FUR-001  Conference Tables   292.100      FUR-001  Conference Tables
# 1       FUR-001  Conference Tables   292.100      FUR-003               Lamp
# 2       FUR-001  Conference Tables   292.100      OFF-001            Crayons
# 3       FUR-001  Conference Tables   292.100      TEC-001     Wireless Mouse
# 4       FUR-001  Conference Tables   292.100      TEC-003        Flash Drive
# 5       FUR-002          Bookcases  3406.664      FUR-001  Conference Tables
# 6       FUR-002          Bookcases  3406.664      FUR-003               Lamp
# 7       FUR-002          Bookcases  3406.664      OFF-001            Crayons
# 8       FUR-002          Bookcases  3406.664      TEC-001     Wireless Mouse
# 9       FUR-002          Bookcases  3406.664      TEC-003        Flash Drive
# 10      TEC-001     Wireless Mouse    39.992      FUR-001  Conference Tables
# 11      TEC-001     Wireless Mouse    39.992      FUR-003               Lamp
# 12      TEC-001     Wireless Mouse    39.992      OFF-001            Crayons
# 13      TEC-001     Wireless Mouse    39.992      TEC-001     Wireless Mouse
# 14      TEC-001     Wireless Mouse    39.992      TEC-003        Flash Drive
# 15      TEC-002            Headset    22.000      FUR-001  Conference Tables
# 16      TEC-002            Headset    22.000      FUR-003               Lamp
# 17      TEC-002            Headset    22.000      OFF-001            Crayons
# 18      TEC-002            Headset    22.000      TEC-001     Wireless Mouse
# 19      TEC-002            Headset    22.000      TEC-003        Flash Drive
#
#            Category
# 0         Furniture
# 1         Furniture
# 2   Office Supplies
# 3        Technology
# 4        Technology
# 5         Furniture
# 6         Furniture
# 7   Office Supplies
# 8        Technology
# 9        Technology
# 10        Furniture
# 11        Furniture
# 12  Office Supplies
# 13       Technology
# 14       Technology
# 15        Furniture
# 16        Furniture
# 17  Office Supplies
# 18       Technology
# 19       Technology

# %% [markdown]
# # **Join**

# %% [markdown]
# > A bit more complex than `.merge()` but can do a lot of the same things.

# %% [markdown]
# This enables you to specify only one DataFrame, which will join the DataFrame you call `.join()` on.
#
# Important thing to know about `.join()` is that it joins on indices and doesn’t directly merge DataFrames.
#
# All columns—even those with matching names—are retained in the resulting DataFrame.

# %%
# df1.join(df2)

# %%
df1.index.name

# %%
df1.set_index('Product ID', inplace=True)

# %%
df1.index.name
# Out:
# 'Product ID'

# %%
df2.set_index('Product ID', inplace=True)

# %%
df1.join(df2, lsuffix='_Left', rsuffix='_Right')
# Out:
#             Product Name_Left     Price Product Name_Right    Category
# Product ID
# FUR-001     Conference Tables   292.100  Conference Tables   Furniture
# FUR-002             Bookcases  3406.664                NaN         NaN
# TEC-001        Wireless Mouse    39.992     Wireless Mouse  Technology
# TEC-002               Headset    22.000                NaN         NaN

# %% [markdown]
# `df1.join(df2)`
# - by default uses the index of `df1`.
#
#   can be overridden by specifying `df1.join(df2, on=key_or_keys)`
# - by default does a left join (keeps all rows of `df1`)
# - always joins via the index of `df2`

# %% [markdown]
# `lsuffix` / `rsuffix` adds a suffix for columns with matching names.
#
# `how` same with merge but uses `left` as default (keeping all rows of `df1`)

# %%
df1.join(df2, how='inner', lsuffix='_Left', rsuffix='_Right')
# Out:
#             Product Name_Left    Price Product Name_Right    Category
# Product ID
# FUR-001     Conference Tables  292.100  Conference Tables   Furniture
# TEC-001        Wireless Mouse   39.992     Wireless Mouse  Technology

# %%
df1.join(df2, on='Product Name', how='outer', lsuffix='_Left', rsuffix='_Right')
# Out:
#               Product Name  Product Name_Left     Price Product Name_Right  \
# FUR-002          Bookcases          Bookcases  3406.664                NaN
# FUR-001  Conference Tables  Conference Tables   292.100                NaN
# NaN                FUR-001                NaN       NaN  Conference Tables
# NaN                FUR-003                NaN       NaN               Lamp
# TEC-002            Headset            Headset    22.000                NaN
# NaN                OFF-001                NaN       NaN            Crayons
# NaN                TEC-001                NaN       NaN     Wireless Mouse
# NaN                TEC-003                NaN       NaN        Flash Drive
# TEC-001     Wireless Mouse     Wireless Mouse    39.992                NaN
#
#                 Category
# FUR-002              NaN
# FUR-001              NaN
# NaN            Furniture
# NaN            Furniture
# TEC-002              NaN
# NaN      Office Supplies
# NaN           Technology
# NaN           Technology
# TEC-001              NaN

# %% [markdown]
# `on` - specifies an optional column or index name for the left DataFrame to join the other DataFrame’s index.
#
#   - default is None, an index-on-index join.
#
# `how` - has the same options as how from merge().
#
# `lsuffix` `rsuffix` - are similar to suffixes in merge().

# %%
df3 = pd.read_csv('product_order.csv')

# %%
df3
# Out:
#          Order ID Customer ID    Customer Name  Product
# 0  CA-2017-152156    HP-14815    Harold Pawlan  TEC-003
# 1  CA-2017-152156    AG-10270  Alejandro Grove  FUR-001
# 2  CA-2017-138688    TB-21520  Tracy Blumstein  OFF-001
# 3  US-2016-108966    SN-20710     Steve Nguyen  TEC-001

# %%
df3.join(df2, on='Product', how='inner')
# Out:
#          Order ID Customer ID    Customer Name  Product       Product Name  \
# 0  CA-2017-152156    HP-14815    Harold Pawlan  TEC-003        Flash Drive
# 1  CA-2017-152156    AG-10270  Alejandro Grove  FUR-001  Conference Tables
# 2  CA-2017-138688    TB-21520  Tracy Blumstein  OFF-001            Crayons
# 3  US-2016-108966    SN-20710     Steve Nguyen  TEC-001     Wireless Mouse
#
#           Category
# 0       Technology
# 1        Furniture
# 2  Office Supplies
# 3       Technology

# %% [markdown]
# Not gonna work with `.merge()` because it uses same name columns for merging.
#
# We can do `left_on` and `right_on` instead.

# %%
# df3.merge(df2, on='Product', how='inner')

# %%
df3.merge(df2, how='inner', left_on='Product', right_on='Product ID')
# Out:
#          Order ID Customer ID    Customer Name  Product       Product Name  \
# 0  CA-2017-152156    HP-14815    Harold Pawlan  TEC-003        Flash Drive
# 1  CA-2017-152156    AG-10270  Alejandro Grove  FUR-001  Conference Tables
# 2  CA-2017-138688    TB-21520  Tracy Blumstein  OFF-001            Crayons
# 3  US-2016-108966    SN-20710     Steve Nguyen  TEC-001     Wireless Mouse
#
#           Category
# 0       Technology
# 1        Furniture
# 2  Office Supplies
# 3       Technology

# %% [markdown]
# # **Concat**

# %%
pd.concat([df1,df2], axis=0, join='outer', sort=False)
# Out:
#                  Product Name     Price         Category
# Product ID
# FUR-001     Conference Tables   292.100              NaN
# FUR-002             Bookcases  3406.664              NaN
# TEC-001        Wireless Mouse    39.992              NaN
# TEC-002               Headset    22.000              NaN
# FUR-001     Conference Tables       NaN        Furniture
# FUR-003                  Lamp       NaN        Furniture
# OFF-001               Crayons       NaN  Office Supplies
# TEC-001        Wireless Mouse       NaN       Technology
# TEC-003           Flash Drive       NaN       Technology

# %%
pd.concat([df1,df2], axis=0, join='inner', sort=False)
# Out:
#                  Product Name
# Product ID
# FUR-001     Conference Tables
# FUR-002             Bookcases
# TEC-001        Wireless Mouse
# TEC-002               Headset
# FUR-001     Conference Tables
# FUR-003                  Lamp
# OFF-001               Crayons
# TEC-001        Wireless Mouse
# TEC-003           Flash Drive

# %%
pd.concat([df1,df2], axis=1, join='outer', sort=False)
# Out:
#                  Product Name     Price       Product Name         Category
# Product ID
# FUR-001     Conference Tables   292.100  Conference Tables        Furniture
# FUR-002             Bookcases  3406.664                NaN              NaN
# TEC-001        Wireless Mouse    39.992     Wireless Mouse       Technology
# TEC-002               Headset    22.000                NaN              NaN
# FUR-003                   NaN       NaN               Lamp        Furniture
# OFF-001                   NaN       NaN            Crayons  Office Supplies
# TEC-003                   NaN       NaN        Flash Drive       Technology

# %%
pd.concat([df1,df2], axis=1, join='inner', sort=False)
# Out:
#                  Product Name    Price       Product Name    Category
# Product ID
# FUR-001     Conference Tables  292.100  Conference Tables   Furniture
# TEC-001        Wireless Mouse   39.992     Wireless Mouse  Technology

# %%
df1.merge(df2, how='inner')
# Out:
#         Product Name    Price    Category
# 0  Conference Tables  292.100   Furniture
# 1     Wireless Mouse   39.992  Technology
