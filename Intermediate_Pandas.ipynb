# %%
import pandas as pd

# %%
zara = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/[Datasets] - Intermediate Pandas/zara.csv')

# %%
zara
# Out:
#      Product ID     Release Product Position Section     Terms  \
# 0      179801.0  2023-10-21   Front of Store     Man   Jackets
# 1      183243.0  2023-07-01   Front of Store     NaN   Jackets
# 2      177771.0  2023-01-22          End-cap     Man  T-Shirts
# 3      177771.0  2023-01-22          End-cap     Man  T-Shirts
# 4           NaN         NaN              NaN     NaN       NaN
# ..          ...         ...              ...     ...       ...
# 269    125409.0  2023-04-08          End-cap     Man   Jackets
# 270    190238.0  2024-03-08   Front of Store     Man   Jackets
# 271    183074.0  2024-01-29            Aisle     Man   Jackets
# 272    199368.0  2023-12-11   Front of Store     NaN   Jackets
# 273    176666.0  2024-03-26            Aisle     Man     Shoes
#
#                   SKU                               Name  \
# 0     311307255-800-2  Contrasting Patches Bomber Jacket
# 1    328250627-251-46                        Suit Jacket
# ...

# %%
zara.shape
# Out:
# (274, 12)

# %%
zara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        259 non-null    float64
#  1   Release           259 non-null    object
#  2   Product Position  259 non-null    object
#  3   Section           245 non-null    object
#  4   Terms             259 non-null    object
#  5   SKU               259 non-null    object
#  6   Name              259 non-null    object
#  7   Description       250 non-null    object
#  8   Seasonal          259 non-null    object
#  9   Promotion         259 non-null    object
#  10  Price             259 non-null    float64
#  11  Sales Volume      259 non-null    float64
# dtypes: float64(3), object(9)
# memory usage: 25.8+ KB

# %%
zara.isnull().sum().sum()
# Out:
# 203

# %%
zara.duplicated().sum()
# Out:
# 19

# %% [markdown]
# # Handling Null Values

# %%
df = zara.copy()

# %%
df.isnull().sum()
# Out:
# Product ID          15
# Release             15
# Product Position    15
# Section             29
# Terms               15
# SKU                 15
# Name                15
# Description         24
# Seasonal            15
# Promotion           15
# Price               15
# Sales Volume        15
# dtype: int64

# %% [markdown]
# ## Drop Null Values

# %%
df.head(10)
# Out:
#    Product ID     Release Product Position Section     Terms  \
# 0    179801.0  2023-10-21   Front of Store     Man   Jackets
# 1    183243.0  2023-07-01   Front of Store     NaN   Jackets
# 2    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 3    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 4         NaN         NaN              NaN     NaN       NaN
# 5    166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6    178281.0  2024-03-08          End-cap     Man   Jackets
# 7    155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8    199233.0  2024-01-15            Aisle     Man   Jackets
# 9    181502.0  2023-11-07   Front of Store   Woman  Sweaters
#
#                 SKU                                      Name  \
# 0   311307255-800-2         Contrasting Patches Bomber Jacket
# 1  328250627-251-46                               Suit Jacket
# 2   281883711-071-2                               Suit Jacket
# ...

# %%
df.dropna(how='any')
# Out:
#      Product ID     Release Product Position Section     Terms  \
# 0      179801.0  2023-10-21   Front of Store     Man   Jackets
# 2      177771.0  2023-01-22          End-cap     Man  T-Shirts
# 3      177771.0  2023-01-22          End-cap     Man  T-Shirts
# 5      166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6      178281.0  2024-03-08          End-cap     Man   Jackets
# ..          ...         ...              ...     ...       ...
# 268    194339.0  2023-05-07          End-cap     Man   Jackets
# 269    125409.0  2023-04-08          End-cap     Man   Jackets
# 270    190238.0  2024-03-08   Front of Store     Man   Jackets
# 271    183074.0  2024-01-29            Aisle     Man   Jackets
# 273    176666.0  2024-03-26            Aisle     Man     Shoes
#
#                   SKU                                      Name  \
# 0     311307255-800-2         Contrasting Patches Bomber Jacket
# 2     281883711-071-2                               Suit Jacket
# ...

# %%
df = df.dropna(how='all')

# %%
df.isnull().sum()
# Out:
# Product ID           0
# Release              0
# Product Position     0
# Section             14
# Terms                0
# SKU                  0
# Name                 0
# Description          9
# Seasonal             0
# Promotion            0
# Price                0
# Sales Volume         0
# dtype: int64

# %% [markdown]
# ## Fill in with non-null values

# %%
df1 = zara.copy()

# %%
df1.head(10)
# Out:
#    Product ID     Release Product Position Section     Terms  \
# 0    179801.0  2023-10-21   Front of Store     Man   Jackets
# 1    183243.0  2023-07-01   Front of Store     NaN   Jackets
# 2    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 3    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 4         NaN         NaN              NaN     NaN       NaN
# 5    166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6    178281.0  2024-03-08          End-cap     Man   Jackets
# 7    155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8    199233.0  2024-01-15            Aisle     Man   Jackets
# 9    181502.0  2023-11-07   Front of Store   Woman  Sweaters
#
#                 SKU                                      Name  \
# 0   311307255-800-2         Contrasting Patches Bomber Jacket
# 1  328250627-251-46                               Suit Jacket
# 2   281883711-071-2                               Suit Jacket
# ...

# %%
df1.fillna('abc').head(10)
# Out:
#   Product ID     Release Product Position Section     Terms               SKU  \
# 0   179801.0  2023-10-21   Front of Store     Man   Jackets   311307255-800-2
# 1   183243.0  2023-07-01   Front of Store     abc   Jackets  328250627-251-46
# 2   177771.0  2023-01-22          End-cap     Man  T-Shirts   281883711-071-2
# 3   177771.0  2023-01-22          End-cap     Man  T-Shirts   281883711-071-2
# 4        abc         abc              abc     abc       abc               abc
# 5   166331.0  2023-07-09            Aisle   Woman  Sweaters   324186867-642-2
# 6   178281.0  2024-03-08          End-cap     Man   Jackets   315758723-401-2
# 7   155848.0  2023-04-24          End-cap   Woman  Sweaters   324597432-800-2
# 8   199233.0  2024-01-15            Aisle     Man   Jackets   330590505-500-2
# 9   181502.0  2023-11-07   Front of Store   Woman  Sweaters   323175653-803-2
#
#                                        Name  \
# 0         Contrasting Patches Bomber Jacket
# ...

# %%
df1.head(10)
# Out:
#    Product ID     Release Product Position Section     Terms  \
# 0    179801.0  2023-10-21   Front of Store     Man   Jackets
# 1    183243.0  2023-07-01   Front of Store     NaN   Jackets
# 2    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 3    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 4         NaN         NaN              NaN     NaN       NaN
# 5    166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6    178281.0  2024-03-08          End-cap     Man   Jackets
# 7    155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8    199233.0  2024-01-15            Aisle     Man   Jackets
# 9    181502.0  2023-11-07   Front of Store   Woman  Sweaters
#
#                 SKU                                      Name  \
# 0   311307255-800-2         Contrasting Patches Bomber Jacket
# 1  328250627-251-46                               Suit Jacket
# 2   281883711-071-2                               Suit Jacket
# ...

# %%
df1.ffill().head(10)
# Out:
#    Product ID     Release Product Position Section     Terms  \
# 0    179801.0  2023-10-21   Front of Store     Man   Jackets
# 1    183243.0  2023-07-01   Front of Store     Man   Jackets
# 2    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 3    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 4    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 5    166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6    178281.0  2024-03-08          End-cap     Man   Jackets
# 7    155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8    199233.0  2024-01-15            Aisle     Man   Jackets
# 9    181502.0  2023-11-07   Front of Store   Woman  Sweaters
#
#                 SKU                                      Name  \
# 0   311307255-800-2         Contrasting Patches Bomber Jacket
# 1  328250627-251-46                               Suit Jacket
# 2   281883711-071-2                               Suit Jacket
# ...

# %%
df1.bfill().head(10)
# Out:
#    Product ID     Release Product Position Section     Terms  \
# 0    179801.0  2023-10-21   Front of Store     Man   Jackets
# 1    183243.0  2023-07-01   Front of Store     Man   Jackets
# 2    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 3    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 4    166331.0  2023-07-09            Aisle   Woman  Sweaters
# 5    166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6    178281.0  2024-03-08          End-cap     Man   Jackets
# 7    155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8    199233.0  2024-01-15            Aisle     Man   Jackets
# 9    181502.0  2023-11-07   Front of Store   Woman  Sweaters
#
#                 SKU                                      Name  \
# 0   311307255-800-2         Contrasting Patches Bomber Jacket
# 1  328250627-251-46                               Suit Jacket
# 2   281883711-071-2                               Suit Jacket
# ...

# %%
df1['Section'].bfill().head(10)
# Out:
# 0      Man
# 1      Man
# 2      Man
# 3      Man
# 4    Woman
# 5    Woman
# 6      Man
# 7    Woman
# 8      Man
# 9    Woman
# Name: Section, dtype: object

# %%
df = df.fillna('N/A')

# %%
df.isnull().sum()
# Out:
# Product ID          0
# Release             0
# Product Position    0
# Section             0
# Terms               0
# SKU                 0
# Name                0
# Description         0
# Seasonal            0
# Promotion           0
# Price               0
# Sales Volume        0
# dtype: int64

# %% [markdown]
# # Removing Duplicates

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df.loc[df.duplicated(keep='last')]
# Out:
#      Product ID     Release Product Position Section     Terms  \
# 2      177771.0  2023-01-22          End-cap     Man  T-Shirts
# 45     138505.0  2023-10-27   Front of Store     Man   Jackets
# 63     182866.0  2023-03-31            Aisle   Woman  Sweaters
# 141    120228.0  2023-01-28          End-cap     Man   Jackets
# 260    147947.0  2023-10-21            Aisle     Man   Jackets
#
#                   SKU                             Name  \
# 2     281883711-071-2                      Suit Jacket
# 45    335663355-406-2              Ripped Denim Jacket
# 63    313890656-800-2        Knit Sweater With Buttons
# 141   327116625-505-2  100% Feather Fill Puffer Jacket
# 260  311297724-700-97      Faux Shearling Plaid Jacket
#
#                                            Description Seasonal Promotion  \
# 2    Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 45   Denim jacket with lapel collar and long sleeve...       No        No
# ...

# %%
df.drop_duplicates(keep='first').head(10)
# Out:
#     Product ID     Release Product Position Section     Terms  \
# 0     179801.0  2023-10-21   Front of Store     Man   Jackets
# 1     183243.0  2023-07-01   Front of Store     N/A   Jackets
# 2     177771.0  2023-01-22          End-cap     Man  T-Shirts
# 5     166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6     178281.0  2024-03-08          End-cap     Man   Jackets
# 7     155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8     199233.0  2024-01-15            Aisle     Man   Jackets
# 9     181502.0  2023-11-07   Front of Store   Woman  Sweaters
# 10    174708.0  2023-03-05   Front of Store     Man  Sweaters
# 11    175059.0  2023-08-19            Aisle     Man   Jackets
#
#                  SKU                                      Name  \
# 0    311307255-800-2         Contrasting Patches Bomber Jacket
# 1   328250627-251-46                               Suit Jacket
# 2    281883711-071-2                               Suit Jacket
# ...

# %%
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Adding / Dropping Columns

# %%
df = df.drop('Description', axis='columns')

# %%
df.head(10)
# Out:
#     Product ID     Release Product Position Section     Terms  \
# 0     179801.0  2023-10-21   Front of Store     Man   Jackets
# 1     183243.0  2023-07-01   Front of Store     N/A   Jackets
# 2     177771.0  2023-01-22          End-cap     Man  T-Shirts
# 5     166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6     178281.0  2024-03-08          End-cap     Man   Jackets
# 7     155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8     199233.0  2024-01-15            Aisle     Man   Jackets
# 9     181502.0  2023-11-07   Front of Store   Woman  Sweaters
# 10    174708.0  2023-03-05   Front of Store     Man  Sweaters
# 11    175059.0  2023-08-19            Aisle     Man   Jackets
#
#                  SKU                                      Name Seasonal  \
# 0    311307255-800-2         Contrasting Patches Bomber Jacket      Yes
# 1   328250627-251-46                               Suit Jacket       No
# ...

# %%
del df['SKU']

# %%
df.head()
# Out:
#    Product ID     Release Product Position Section     Terms  \
# 0    179801.0  2023-10-21   Front of Store     Man   Jackets
# 1    183243.0  2023-07-01   Front of Store     N/A   Jackets
# 2    177771.0  2023-01-22          End-cap     Man  T-Shirts
# 5    166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6    178281.0  2024-03-08          End-cap     Man   Jackets
#
#                                        Name Seasonal Promotion  Price  \
# 0         Contrasting Patches Bomber Jacket      Yes        No  169.0
# 1                               Suit Jacket       No       Yes  169.0
# 2                               Suit Jacket      Yes       Yes   69.9
# 5  Asymmetrical Wool And Silk Blend Sweater      Yes       Yes   59.9
# 6                             Bomber Jacket      Yes        No  169.0
#
#    Sales Volume
# 0        2608.0
# 1        1524.0
# 2        1764.0
# 5        2877.0
# 6        1145.0

# %%
df['Brand'] = ['Zara']*len(df)

# %%
df.head(10)
# Out:
#     Product ID     Release Product Position Section     Terms  \
# 0     179801.0  2023-10-21   Front of Store     Man   Jackets
# 1     183243.0  2023-07-01   Front of Store     N/A   Jackets
# 2     177771.0  2023-01-22          End-cap     Man  T-Shirts
# 5     166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6     178281.0  2024-03-08          End-cap     Man   Jackets
# 7     155848.0  2023-04-24          End-cap   Woman  Sweaters
# 8     199233.0  2024-01-15            Aisle     Man   Jackets
# 9     181502.0  2023-11-07   Front of Store   Woman  Sweaters
# 10    174708.0  2023-03-05   Front of Store     Man  Sweaters
# 11    175059.0  2023-08-19            Aisle     Man   Jackets
#
#                                         Name Seasonal Promotion  Price  \
# 0          Contrasting Patches Bomber Jacket      Yes        No  169.0
# 1                                Suit Jacket       No       Yes  169.0
# ...

# %%
df.insert(2, 'Country', ['PH']*len(df))

# %%
df.head(10)
# Out:
#     Product ID     Release Country Product Position Section     Terms  \
# 0     179801.0  2023-10-21      PH   Front of Store     Man   Jackets
# 1     183243.0  2023-07-01      PH   Front of Store     N/A   Jackets
# 2     177771.0  2023-01-22      PH          End-cap     Man  T-Shirts
# 5     166331.0  2023-07-09      PH            Aisle   Woman  Sweaters
# 6     178281.0  2024-03-08      PH          End-cap     Man   Jackets
# 7     155848.0  2023-04-24      PH          End-cap   Woman  Sweaters
# 8     199233.0  2024-01-15      PH            Aisle     Man   Jackets
# 9     181502.0  2023-11-07      PH   Front of Store   Woman  Sweaters
# 10    174708.0  2023-03-05      PH   Front of Store     Man  Sweaters
# 11    175059.0  2023-08-19      PH            Aisle     Man   Jackets
#
#                                         Name Seasonal Promotion  Price  \
# 0          Contrasting Patches Bomber Jacket      Yes        No  169.0
# ...

# %%
df['Total Sales'] = df['Price']*df['Sales Volume']

# %%
df
# Out:
#      Product ID     Release Country Product Position Section     Terms  \
# 0      179801.0  2023-10-21      PH   Front of Store     Man   Jackets
# 1      183243.0  2023-07-01      PH   Front of Store     N/A   Jackets
# 2      177771.0  2023-01-22      PH          End-cap     Man  T-Shirts
# 5      166331.0  2023-07-09      PH            Aisle   Woman  Sweaters
# 6      178281.0  2024-03-08      PH          End-cap     Man   Jackets
# ..          ...         ...     ...              ...     ...       ...
# 269    125409.0  2023-04-08      PH          End-cap     Man   Jackets
# 270    190238.0  2024-03-08      PH   Front of Store     Man   Jackets
# 271    183074.0  2024-01-29      PH            Aisle     Man   Jackets
# 272    199368.0  2023-12-11      PH   Front of Store     N/A   Jackets
# 273    176666.0  2024-03-26      PH            Aisle     Man     Shoes
#
#                                          Name Seasonal Promotion  Price  \
# ...

# %%
del df['Brand']
del df['Country']

# %%
df
# Out:
#      Product ID     Release Product Position Section     Terms  \
# 0      179801.0  2023-10-21   Front of Store     Man   Jackets
# 1      183243.0  2023-07-01   Front of Store     N/A   Jackets
# 2      177771.0  2023-01-22          End-cap     Man  T-Shirts
# 5      166331.0  2023-07-09            Aisle   Woman  Sweaters
# 6      178281.0  2024-03-08          End-cap     Man   Jackets
# ..          ...         ...              ...     ...       ...
# 269    125409.0  2023-04-08          End-cap     Man   Jackets
# 270    190238.0  2024-03-08   Front of Store     Man   Jackets
# 271    183074.0  2024-01-29            Aisle     Man   Jackets
# 272    199368.0  2023-12-11   Front of Store     N/A   Jackets
# 273    176666.0  2024-03-26            Aisle     Man     Shoes
#
#                                          Name Seasonal Promotion  Price  \
# 0           Contrasting Patches Bomber Jacket      Yes        No  169.0
# ...

# %% [markdown]
# # Merge and Join

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/[Datasets] - Intermediate Pandas/product_cat.csv')

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/[Datasets] - Intermediate Pandas/product_price.csv')

# %%
df1
# Out:
#   Product ID       Product Name         Category
# 0    FUR-001  Conference Tables        Furniture
# 1    FUR-003               Lamp        Furniture
# 2    OFF-001            Crayons  Office Supplies
# 3    TEC-001     Wireless Mouse       Technology
# 4    TEC-003        Flash Drive       Technology

# %%
df2
# Out:
#   Product ID       Product Name     Price
# 0    FUR-001  Conference Tables   292.100
# 1    FUR-002          Bookcases  3406.664
# 2    TEC-001     Wireless Mouse    39.992
# 3    TEC-002            Headset    22.000

# %%
df1.merge(df2)
# Out:
#   Product ID       Product Name    Category    Price
# 0    FUR-001  Conference Tables   Furniture  292.100
# 1    TEC-001     Wireless Mouse  Technology   39.992

# %%
df1.merge(df2, how='outer')
# Out:
#   Product ID       Product Name         Category     Price
# 0    FUR-001  Conference Tables        Furniture   292.100
# 1    FUR-002          Bookcases              NaN  3406.664
# 2    FUR-003               Lamp        Furniture       NaN
# 3    OFF-001            Crayons  Office Supplies       NaN
# 4    TEC-001     Wireless Mouse       Technology    39.992
# 5    TEC-002            Headset              NaN    22.000
# 6    TEC-003        Flash Drive       Technology       NaN

# %%
df1.merge(df2, how='left')
# Out:
#   Product ID       Product Name         Category    Price
# 0    FUR-001  Conference Tables        Furniture  292.100
# 1    FUR-003               Lamp        Furniture      NaN
# 2    OFF-001            Crayons  Office Supplies      NaN
# 3    TEC-001     Wireless Mouse       Technology   39.992
# 4    TEC-003        Flash Drive       Technology      NaN

# %%
df1.merge(df2, how='right')
# Out:
#   Product ID       Product Name    Category     Price
# 0    FUR-001  Conference Tables   Furniture   292.100
# 1    FUR-002          Bookcases         NaN  3406.664
# 2    TEC-001     Wireless Mouse  Technology    39.992
# 3    TEC-002            Headset         NaN    22.000

# %%
df1.merge(df2, how='inner', on=['Product ID'])
# Out:
#   Product ID     Product Name_x    Category     Product Name_y    Price
# 0    FUR-001  Conference Tables   Furniture  Conference Tables  292.100
# 1    TEC-001     Wireless Mouse  Technology     Wireless Mouse   39.992

# %%
df1.merge(df2, how='inner', on=['Product ID'], suffixes=('_Left', '_Right'))
# Out:
#   Product ID  Product Name_Left    Category Product Name_Right    Price
# 0    FUR-001  Conference Tables   Furniture  Conference Tables  292.100
# 1    TEC-001     Wireless Mouse  Technology     Wireless Mouse   39.992

# %% [markdown]
# ## Join

# %%
df1.index.name

# %%
df2.index.name

# %%
df1 = df1.set_index(['Product ID'])
df2 = df2.set_index(['Product ID'])

# %%
df1
# Out:
#                  Product Name         Category
# Product ID
# FUR-001     Conference Tables        Furniture
# FUR-003                  Lamp        Furniture
# OFF-001               Crayons  Office Supplies
# TEC-001        Wireless Mouse       Technology
# TEC-003           Flash Drive       Technology

# %%
df2
# Out:
#                  Product Name     Price
# Product ID
# FUR-001     Conference Tables   292.100
# FUR-002             Bookcases  3406.664
# TEC-001        Wireless Mouse    39.992
# TEC-002               Headset    22.000

# %%
df1.join(df2, lsuffix='_Left', rsuffix='_Right')
# Out:
#             Product Name_Left         Category Product Name_Right    Price
# Product ID
# FUR-001     Conference Tables        Furniture  Conference Tables  292.100
# FUR-003                  Lamp        Furniture                NaN      NaN
# OFF-001               Crayons  Office Supplies                NaN      NaN
# TEC-001        Wireless Mouse       Technology     Wireless Mouse   39.992
# TEC-003           Flash Drive       Technology                NaN      NaN

# %%
df1.join(df2, how='right', lsuffix='_Left', rsuffix='_Right')
# Out:
#             Product Name_Left    Category Product Name_Right     Price
# Product ID
# FUR-001     Conference Tables   Furniture  Conference Tables   292.100
# FUR-002                   NaN         NaN          Bookcases  3406.664
# TEC-001        Wireless Mouse  Technology     Wireless Mouse    39.992
# TEC-002                   NaN         NaN            Headset    22.000

# %%
df1.join(df2, how='left', lsuffix='_Left', rsuffix='_Right', on='Product Name')
# Out:
#                  Product Name  Product Name_Left         Category  \
# Product ID
# FUR-001     Conference Tables  Conference Tables        Furniture
# FUR-003                  Lamp               Lamp        Furniture
# OFF-001               Crayons            Crayons  Office Supplies
# TEC-001        Wireless Mouse     Wireless Mouse       Technology
# TEC-003           Flash Drive        Flash Drive       Technology
#
#            Product Name_Right  Price
# Product ID
# FUR-001                   NaN    NaN
# FUR-003                   NaN    NaN
# OFF-001                   NaN    NaN
# TEC-001                   NaN    NaN
# TEC-003                   NaN    NaN

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/[Datasets] - Intermediate Pandas/product_order.csv')

# %%
df3
# Out:
#                Customer ID    Customer Name  Product
# Order ID
# CA-2017-152156    HP-14815    Harold Pawlan  TEC-003
# CA-2017-152156    AG-10270  Alejandro Grove  FUR-001
# CA-2017-138688    TB-21520  Tracy Blumstein  OFF-001
# US-2016-108966    SN-20710     Steve Nguyen  TEC-001

# %%
df3 = df3.set_index('Order ID')

# %%
df1
# Out:
#                  Product Name         Category
# Product ID
# FUR-001     Conference Tables        Furniture
# FUR-003                  Lamp        Furniture
# OFF-001               Crayons  Office Supplies
# TEC-001        Wireless Mouse       Technology
# TEC-003           Flash Drive       Technology

# %%
df3.join(df1, how='left', on='Product')
# Out:
#                Customer ID    Customer Name  Product       Product Name  \
# Order ID
# CA-2017-152156    HP-14815    Harold Pawlan  TEC-003        Flash Drive
# CA-2017-152156    AG-10270  Alejandro Grove  FUR-001  Conference Tables
# CA-2017-138688    TB-21520  Tracy Blumstein  OFF-001            Crayons
# US-2016-108966    SN-20710     Steve Nguyen  TEC-001     Wireless Mouse
#
#                        Category
# Order ID
# CA-2017-152156       Technology
# CA-2017-152156        Furniture
# CA-2017-138688  Office Supplies
# US-2016-108966       Technology

# %%
df3.merge(df1, how='left', left_on='Product', right_on='Product ID')
# Out:
#   Customer ID    Customer Name  Product       Product Name         Category
# 0    HP-14815    Harold Pawlan  TEC-003        Flash Drive       Technology
# 1    AG-10270  Alejandro Grove  FUR-001  Conference Tables        Furniture
# 2    TB-21520  Tracy Blumstein  OFF-001            Crayons  Office Supplies
# 3    SN-20710     Steve Nguyen  TEC-001     Wireless Mouse       Technology
